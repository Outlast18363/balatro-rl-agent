# %%
class ShopEmbeddings(nn.Module):

# %%
class ShopBackbone(nn.Module):

# %%
class ShopHeads(nn.Module):

# %%
class ShopPPOAgent(nn.Module):
    def __init__(self, d_model=128):
        super().__init__()
        self.embeddings = ShopEmbeddings(d_model=d_model)
        self.backbone = ShopBackbone(d_model=d_model)
        self.heads = ShopHeads(d_model=d_model)

    def forward(self, s):
